# %% [markdown]
# <a href="https://colab.research.google.com/github/veda9-creator/nlp_tutorial/blob/main/tokenize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus= """My name is sriveda. Sribhanu is my sister. Please contact us."""
print(corpus)
# Out:
# My name is sriveda. Sribhanu is my sister. Please contact us.

# %%
##sentence --> paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
# My name is sriveda.
# Sribhanu is my sister.
# Please contact us.

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['My',
#  'name',
#  'is',
#  'sriveda',
#  '.',
#  'Sribhanu',
#  'is',
#  'my',
#  'sister',
#  '.',
#  'Please',
#  'contact',
#  'us',
#  '.']

# %%
for sentences in documents:
  print(word_tokenize(sentences))
# Out:
# ['My', 'name', 'is', 'sriveda', '.']
# ['Sribhanu', 'is', 'my', 'sister', '.']
# ['Please', 'contact', 'us', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['My',
#  'name',
#  'is',
#  'sriveda',
#  '.',
#  'Sribhanu',
#  'is',
#  'my',
#  'sister',
#  '.',
#  'Please',
#  'contact',
#  'us',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer

# %%
tokenizer= TreebankWordDetokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# 'M y   n a m e   i s   s r i v e d a .   S r i b h a n u   i s   m y   s i s t e r .   P l e a s e   c o n t a c t   u s.'

# %%
# Stemming
words=["eating","eat","eaten","writing","write","programs","programming"]

# %%
from nltk.stem import PorterStemmer

# %%
stemming= PorterStemmer()

# %%
for word in words:
  print(word+"----->"+stemming.stem(word))
# Out:
# eating----->eat
# eat----->eat
# eaten----->eaten
# writing----->write
# write----->write
# programs----->program
# programming----->program

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|able$', min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
##snowball stemmer
from nltk.stem import SnowballStemmer

# %%
snowball_stemmer=SnowballStemmer('english')

# %%
for word in words:
  print(word+"----->"+snowball_stemmer.stem(word))
# Out:
# eating----->eat
# eat----->eat
# eaten----->eaten
# writing----->write
# write----->write
# programs----->program
# programming----->program

# %%
stemming.stem("fairly")
# Out:
# 'fairli'

# %%
snowball_stemmer.stem("fairly")
# Out:
# 'fair'

# %%
snowball_stemmer.stem("goes")
# Out:
# 'goe'

# %%
##Lemmatization
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer= WordNetLemmatizer()

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
lemmatizer.lemmatize("going",pos='v')
lemmatizer.lemmatize("going",pos='a')
# Out:
# 'going'

# %%
for word in words:
  print(word+"----->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating----->eat
# eat----->eat
# eaten----->eat
# writing----->write
# write----->write
# programs----->program
# programming----->program

# %%
lemmatizer.lemmatize("fairly",pos='v')
# Out:
# 'fairly'

# %%
## stopwords

# %%
paragraph="""PyTorch is an optimized tensor library for deep learning using GPUs and CPUs.

Features described in this documentation are classified by release status:

Stable (API-Stable): These features will be maintained long-term and there should generally be no major performance limitations or gaps in documentation. We also expect to maintain backwards compatibility (although breaking changes can happen and notice will be given one release ahead of time).

Unstable (API-Unstable): Encompasses all features that are under active development where APIs may change based on user feedback, requisite performance improvements or because coverage across operators is not yet complete. The APIs and performance characteristics of these features may change."""

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
sentences= nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
  words= nltk.word_tokenize(sentences[i])
  words= [stemming.stem(word) for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['pytorch optim tensor librari deep learn use gpu cpu .',
#  'featur describ document classifi releas statu : stabl ( api-st ) : these featur maintain long-term gener major perform limit gap document .',
#  'we also expect maintain backward compat ( although break chang happen notic given one releas ahead time ) .',
#  'unstabl ( api-unst ) : encompass featur activ develop api may chang base user feedback , requisit perform improv coverag across oper yet complet .',
#  'the api perform characterist featur may chang .']

# %%
for i in range(len(sentences)):
  words= nltk.word_tokenize(sentences[i])
  words= [snowball_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['pytorch optim tensor librari deep learn use gpu cpu .',
#  'featur describ document classifi relea statu : stabl ( api-st ) : featur maintain long-term gener major perform limit gap document .',
#  'also expect maintain backward compat ( although break chang happen notic given one relea ahead time ) .',
#  'unstabl ( api-unst ) : encompass featur activ develop api may chang base user feedback , requisit perform improv coverag across oper yet complet .',
#  'api perform characterist featur may chang .']

# %%
for i in range(len(sentences)):
  words= nltk.word_tokenize(sentences[i])
  words= [lemmatizer.lemmatize(word,pos='v') for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['pytorch optim tensor librari deep learn use gpu cpu .',
#  'featur describ document classifi relea statu : stabl ( api-st ) : featur maintain long-term gener major perform limit gap document .',
#  'also expect maintain backward compat ( although break chang happen notic give one relea ahead time ) .',
#  'unstabl ( api-unst ) : encompass featur activ develop api may chang base user feedback , requisit perform improv coverag across oper yet complet .',
#  'api perform characterist featur may chang .']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
for i in range(len(sentences)):
  words= nltk.word_tokenize(sentences[i])
  words= [word for word in words if word not in set(stopwords.words('english'))]
  ##sentences[i] = " ".join(words)
  pos_tag= nltk.pos_tag(words)
  print(pos_tag)
# Out:
# [('pytorch', 'NN'), ('optim', 'NN'), ('tensor', 'NN'), ('librari', 'JJ'), ('deep', 'NN'), ('learn', 'NN'), ('use', 'NN'), ('gpu', 'NN'), ('cpu', 'NN'), ('.', '.')]
# [('featur', 'NN'), ('describ', 'NN'), ('document', 'NN'), ('classifi', 'NN'), ('relea', 'NN'), ('statu', 'NN'), (':', ':'), ('stabl', 'NN'), ('(', '('), ('api-st', 'JJ'), (')', ')'), (':', ':'), ('featur', 'JJ'), ('maintain', 'VBP'), ('long-term', 'JJ'), ('gener', 'NN'), ('major', 'JJ'), ('perform', 'NN'), ('limit', 'NN'), ('gap', 'NN'), ('document', 'NN'), ('.', '.')]
# [('also', 'RB'), ('expect', 'VBP'), ('maintain', 'RB'), ('backward', 'JJ'), ('compat', 'NN'), ('(', '('), ('although', 'IN'), ('break', 'NN'), ('chang', 'NN'), ('happen', 'JJ'), ('notic', 'JJ'), ('give', 'VBP'), ('one', 'CD'), ('relea', 'NN'), ('ahead', 'RB'), ('time', 'NN'), (')', ')'), ('.', '.')]
# ...

# %%
"Taj Mahal is a beautiful monument".split()
# Out:
# ['Taj', 'Mahal', 'is', 'a', 'beautiful', 'monument']

# %%
nltk.pos_tag("Taj Mahal is a beautiful monument".split())
# Out:
# [('Taj', 'NNP'),
#  ('Mahal', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('beautiful', 'JJ'),
#  ('monument', 'NN')]

# %%
##Named Entity Recognition

# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by french engineer Gustav ee fl "

# %%
import nltk
words=word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.9 MB/s eta 0:00:00
# ...

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), ('french', 'JJ'), ('engineer', 'NN'), Tree('PERSON', [('Gustav', 'NNP')]), ('ee', 'VBZ'), ('fl', 'NN')])
